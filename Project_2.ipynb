# %% [markdown]
# ### Global Cuisine Calorie Analysis

# %% [markdown]
# Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading the file

# %%
df = pd.read_csv('cleaned_food_data.csv')

# %% [markdown]
# Checking if the file is loaded

# %%
print(df.head()) # prints only few rows of the file
# Out:
#    Food Name Country/Region  \
# 0      Tacos         Mexico
# 1   Shawarma        Lebanon
# 2    Banh Mi        Vietnam
# 3    Churros          Spain
# 4  Pani Puri          India
#
#                                          Description  Calories Serving Type  \
# 0     Corn tortilla filled with meat and vegetables.       250          Hot
# 1      Middle eastern wrap with meat and vegetables.       400         Cold
# 2  Vietnamese baguette sandwich with pickled vege...       450         Cold
# 3          Sweet fried dough sticks coated in sugar.       350          Hot
# 4     Crispy semolina puffs filled with spicy water.       200         Cold
#
#                             Main Ingredients     Category  Preparation Time  \
# 0            Corn Tortilla, Meat, Vegetables        Snack                20
# 1                Meat, Vegetables, Flatbread  Main Course                30
# 2  Baguette, Pork, Pickled Vegetables, Herbs        Snack                25
# 3                     Flour, Sugar, Cinnamon      Dessert                40
# 4                 Semolina, Potatoes, Spices        Snack                30
#
#    Popularity Rank
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5

# %% [markdown]
# Group data ['Country/Region']

# %%
average_calories_by_country_region = df.groupby('Country/Region')['Calories'].mean()

# Sorted Average Calories data Ascending Order
sorted_average_calories = average_calories_by_country_region.sort_values(ascending = True)

# Top 10 countries
top_10_countries = sorted_average_calories.head(10)

# %% [markdown]
# Plotting

# %%
plt.figure(figsize=(15, 7))
sns.barplot(x = top_10_countries.index, y = top_10_countries.values, palette='rocket')
plt.title("Top 10 countries by average food calories")
plt.xlabel("Country/Region")
plt.ylabel("Average Calories")
plt.show()
# Out:
# /tmp/ipython-input-102311778.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = top_10_countries.index, y = top_10_countries.values, palette='rocket')
